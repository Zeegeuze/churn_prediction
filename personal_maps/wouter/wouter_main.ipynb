# %% [markdown]
# # Notebook Wouter
# ## Preprocessing

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../../data/BankChurners.csv')
df
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
# start with removing the last 2 columns
df = df.iloc[: ,:-2]
df
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %% [markdown]
# ## Check for duplictates

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Check for NA

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# CLIENTNUM                   0
# Attrition_Flag              0
# Customer_Age                0
# Gender                      0
# Dependent_count             0
# Education_Level             0
# Marital_Status              0
# Income_Category             0
# Card_Category               0
# Months_on_book              0
# Total_Relationship_Count    0
# Months_Inactive_12_mon      0
# Contacts_Count_12_mon       0
# Credit_Limit                0
# Total_Revolving_Bal         0
# Avg_Open_To_Buy             0
# Total_Amt_Chng_Q4_Q1        0
# Total_Trans_Amt             0
# Total_Trans_Ct              0
# Total_Ct_Chng_Q4_Q1         0
# Avg_Utilization_Ratio       0
# dtype: int64

# %%
df[['Customer_Age']].boxplot();

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['Months_on_book']);
plt.show()

# %% [markdown]
# ## Ordinal Encode

# %%
from sklearn.preprocessing import OrdinalEncoder

classes = ["Attrition_Flag", "Gender", "Education_Level", "Marital_Status", "Card_Category", "Income_Category"]

# Instantiate the Ordinal Encoder
ordinal_encoder = OrdinalEncoder()

# Fit it
ordinal_encoder.fit(df[classes])

# Display the learned categories
display(ordinal_encoder.categories_)

# Transform categories into ordered numbers
df[classes] = ordinal_encoder.transform(df[classes])
# df[["Attrition_Flag_encoded", "Gender_encoded", "Education_Level_encoded", "Marital_Status_encoded", "Card_Category_encoded"]] = ordinal_encoder.transform(df[classes])


# encoded_df = pd.DataFrame(df[])

# Show the transformed classes
df
# Out:
# [array(['Attrited Customer', 'Existing Customer'], dtype=object),
#  array(['F', 'M'], dtype=object),
#  array(['College', 'Doctorate', 'Graduate', 'High School', 'Post-Graduate',
#         'Uneducated', 'Unknown'], dtype=object),
#  array(['Divorced', 'Married', 'Single', 'Unknown'], dtype=object),
#  array(['Blue', 'Gold', 'Platinum', 'Silver'], dtype=object),
#  array(['$120K +', '$40K - $60K', '$60K - $80K', '$80K - $120K',
#         'Less than $40K', 'Unknown'], dtype=object)]
#        CLIENTNUM  Attrition_Flag  Customer_Age  Gender  Dependent_count  \
# 0      768805383             1.0            45     1.0                3
# 1      818770008             1.0            49     0.0                5
# 2      713982108             1.0            51     1.0                3
# 3      769911858             1.0            40     0.0                4
# 4      709106358             1.0            40     1.0                3
# ...

# %% [markdown]
# ## Let's set the clientnum as index

# %%
df.set_index("CLIENTNUM", inplace=True)

# %%
df
# Out:
#            Attrition_Flag  Customer_Age  Gender  Dependent_count  \
# CLIENTNUM
# 768805383             1.0            45     1.0                3
# 818770008             1.0            49     0.0                5
# 713982108             1.0            51     1.0                3
# 769911858             1.0            40     0.0                4
# 709106358             1.0            40     1.0                3
# ...                   ...           ...     ...              ...
# 772366833             1.0            50     1.0                2
# 710638233             0.0            41     1.0                2
# 716506083             0.0            44     0.0                1
# 717406983             0.0            30     1.0                2
# 714337233             0.0            43     0.0                2
#
#            Education_Level  Marital_Status  Income_Category  Card_Category  \
# CLIENTNUM
# 768805383              3.0             1.0              2.0            0.0
# ...

# %% [markdown]
# ## Check for correlation

# %%
sns.set_theme(style='white')
sns.color_palette("YlOrBr", as_cmap=True)

# Compute the correlation matrix
corr = df.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(250, 15, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5});

# %%
# Heatmap of pairwise correlations
correlation_matrix = df.corr()
column_names = correlation_matrix.columns
sns.heatmap(correlation_matrix, xticklabels=column_names, yticklabels=column_names,cmap= "bwr");

# Converting the correlation matrix into a DataFrame
corr_df = correlation_matrix.stack().reset_index()

# Renaming the columns
corr_df.columns = ['feature_1','feature_2', 'correlation']

# Remove "self correlations"
no_self_correlation = (corr_df['feature_1'] != corr_df['feature_2'])
corr_df = corr_df[no_self_correlation]

# Computing the absolute correlation
corr_df['absolute_correlation'] = np.abs(corr_df['correlation'])

# Showing the top 5 most correlated pairs of feature
corr_df.sort_values(by="absolute_correlation", ascending=False).head(5*2)
# Out:
#                  feature_1              feature_2  correlation  \
# 292        Avg_Open_To_Buy           Credit_Limit     0.995981
# 254           Credit_Limit        Avg_Open_To_Buy     0.995981
# 337        Total_Trans_Amt         Total_Trans_Ct     0.807192
# 356         Total_Trans_Ct        Total_Trans_Amt     0.807192
# 161         Months_on_book           Customer_Age     0.788912
# 28            Customer_Age         Months_on_book     0.788912
# 393  Avg_Utilization_Ratio    Total_Revolving_Bal     0.624022
# 279    Total_Revolving_Bal  Avg_Utilization_Ratio     0.624022
# 46                  Gender        Income_Category    -0.539731
# 122        Income_Category                 Gender    -0.539731
#
#      absolute_correlation
# 292              0.995981
# 254              0.995981
# 337              0.807192
# 356              0.807192
# 161              0.788912
# 28               0.788912
# 393              0.624022
# 279              0.624022
# 46               0.539731
# ...

# %% [markdown]
# ## Let's drop some columns with heavy correlation

# %%
df.drop('Total_Revolving_Bal', axis =1, inplace = True)
df.drop('Credit_Limit', axis =1, inplace = True)

# %% [markdown]
# ## Let's split

# %%
from sklearn.model_selection import train_test_split


X = df.drop(['Attrition_Flag'], axis='columns')
y = df['Attrition_Flag']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ## First model without rebalancing

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report


# Create and train the KNN model
knn = KNeighborsClassifier(n_neighbors=4)
knn.fit(X_train, y_train)

# Predict
y_pred = knn.predict(X_test)

# Evaluate
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.84
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.51      0.52      0.52       496
#          1.0       0.91      0.90      0.90      2543
#
#     accuracy                           0.84      3039
#    macro avg       0.71      0.71      0.71      3039
# weighted avg       0.84      0.84      0.84      3039

# %% [markdown]
# ## Resampling

# %%
imbalance_graph = sns.displot(y_train, bins=2)
imbalance_graph.fig.suptitle('Imbalanced target')

plt.show();

# %%
from collections import Counter
from imblearn.over_sampling import RandomOverSampler

ros = RandomOverSampler(random_state=42)
X_train, y_train = ros.fit_resample(X_train, y_train)
print('Resampled dataset shape %s' % Counter(y_train));
# Out:
# Resampled dataset shape Counter({1.0: 5957, 0.0: 5957})
# /home/wouter/.pyenv/versions/3.10.6/lib/python3.10/site-packages/sklearn/base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# /home/wouter/.pyenv/versions/3.10.6/lib/python3.10/site-packages/sklearn/base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(

# %%
imbalance_graph = sns.displot(y_train, bins=2)
imbalance_graph.fig.suptitle('Imbalanced target')

plt.show();

# %% [markdown]
# ## Modelling

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report


# Create and train the KNN model
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)

# Predict
y_pred = knn.predict(X_test)

# Evaluate
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.81
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.45      0.64      0.53       496
#          1.0       0.92      0.85      0.88      2543
#
#     accuracy                           0.81      3039
#    macro avg       0.68      0.74      0.70      3039
# weighted avg       0.85      0.81      0.82      3039

# %%
from sklearn.inspection import permutation_importance

# Performs Permutation
permutation_score = permutation_importance(knn, X_train, y_train, n_repeats=10)

# Unstack results showing the decrease in performance after shuffling features
importance_df = pd.DataFrame(np.vstack((X_train.columns,
                                        permutation_score.importances_mean)).T)
importance_df.columns=['feature','score decrease']

# Show the important features
importance_df.sort_values(by="score decrease", ascending = False)
# Out:
#                      feature score decrease
# 13           Total_Trans_Amt       0.413295
# 11           Avg_Open_To_Buy       0.240247
# 14            Total_Trans_Ct       0.001754
# 0               Customer_Age       0.000823
# 7             Months_on_book        0.00052
# 1                     Gender            0.0
# 15       Total_Ct_Chng_Q4_Q1            0.0
# 12      Total_Amt_Chng_Q4_Q1            0.0
# 16     Avg_Utilization_Ratio            0.0
# 6              Card_Category            0.0
# 5            Income_Category            0.0
# 4             Marital_Status            0.0
# 3            Education_Level            0.0
# 2            Dependent_count            0.0
# 8   Total_Relationship_Count      -0.000008
# 10     Contacts_Count_12_mon      -0.000034
# 9     Months_Inactive_12_mon      -0.000067

# %%
data = importance_df.sort_values(by="score decrease", ascending = False)

# Create a barplot
sns.set(style="whitegrid")
plt.figure(figsize=(24, 5))
sns.barplot( x="score decrease", hue="feature", data=data, palette="viridis" )

# Add title and labels
plt.title("Barplot Example", fontsize=16)
plt.xlabel("Importance", fontsize=12)
plt.ylabel("Feature", fontsize=12)

# Show the plot
plt.show();

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Define the number of clusters
n_clusters = 4

# Create and fit the KMeans model on the training data
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
kmeans.fit(X_train)

# Predict cluster labels for training and test data
y_train_clusters = kmeans.predict(X_train)
y_test_clusters = kmeans.predict(X_test)

# Visualize the training data clusters
plt.figure(figsize=(8, 6))
plt.scatter(X_train.iloc[:, 0], X_train.iloc[:, 1], c=y_train_clusters, cmap='viridis')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], c='red', s=200, marker='X', label='Centers')
plt.title("KMeans Clustering on Training Data")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.legend()
plt.show()

# Visualize the test data clusters
plt.figure(figsize=(8, 6))
plt.scatter(X_test.iloc[:, 0], X_test.iloc[:, 1], c=y_test_clusters, cmap='viridis', s=30, alpha=0.7)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], c='red', s=200, marker='X', label='Centers')
plt.title("KMeans Clustering on Test Data")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.legend()
plt.show()
